# %%
import yfinance as yf
import pandas as pd
import numpy as np

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

import xgboost as xgb
import shap

import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
dis_df = yf.download("DIS", start="2010-01-01", end="2025-05-30", auto_adjust=True)
dis_df.columns = dis_df.columns.get_level_values(0)

sp500_df = yf.download("^GSPC", start="2010-01-01", end="2025-05-30", auto_adjust=True)
sp500_df.columns = sp500_df.columns.get_level_values(0)

vix_df = yf.download("^VIX", start="2010-01-01", end="2025-05-30", auto_adjust=True)
vix_df.columns = vix_df.columns.get_level_values(0)

data = dis_df[["Open", "High", "Low", "Close", "Volume"]].copy()
data.rename(columns={"Close": "Adj Close"}, inplace=True)

sp500_adj = sp500_df["Close"].rename("SP500")
vix_adj   = vix_df["Close"].rename("VIX")

data = data.join(sp500_adj, how="inner").join(vix_adj, how="inner")
data.dropna(inplace=True)

data.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low   Adj Close    Volume  \
# Date
# 2025-05-22  109.980003  111.800003  109.980003  111.129997   7903700
# 2025-05-23  109.599998  110.349998  108.779999  109.720001   8086100
# 2025-05-27  111.029999  112.889999  110.150002  112.360001  10201100
# 2025-05-28  112.199997  112.470001  111.169998  111.519997   5787900
# 2025-05-29  112.010002  112.260002  110.519997  112.019997   9682100
#
#                   SP500        VIX
# Date
# 2025-05-22  5842.009766  20.280001
# 2025-05-23  5802.819824  22.290001
# 2025-05-27  5921.540039  18.959999
# 2025-05-28  5888.549805  19.309999
# 2025-05-29  5912.169922  19.180000

# %%
def compute_technical_indicators(df):
    """
    Enhanced feature‐engineering pipeline for DIS forecasting. Returns a DataFrame
    with original price/volume columns plus expanded technical/exogenous indicators.
    """
    df = df.copy()

    # 1. Basic log‐returns
    df["log_ret"] = np.log(df["Adj Close"] / df["Adj Close"].shift(1))

    # 2. Simple and exponential moving averages
    df["SMA_5"]   = df["Adj Close"].rolling(window=5).mean()
    df["SMA_10"]  = df["Adj Close"].rolling(window=10).mean()
    df["SMA_20"]  = df["Adj Close"].rolling(window=20).mean()
    df["EMA_10"]  = df["Adj Close"].ewm(span=10, adjust=False).mean()
    df["EMA_20"]  = df["Adj Close"].ewm(span=20, adjust=False).mean()

    # 3. Momentum (10‐day)
    df["MOM_10"]  = df["Adj Close"] / df["Adj Close"].shift(10) - 1

    # 4. Moving Average Convergence/Divergence (MACD: 12,26,9)
    ema12 = df["Adj Close"].ewm(span=12, adjust=False).mean()
    ema26 = df["Adj Close"].ewm(span=26, adjust=False).mean()
    df["MACD"]   = ema12 - ema26
    df["MACD_SIG"] = df["MACD"].ewm(span=9, adjust=False).mean()

    # 5. Bollinger Bands (20‐day, 2σ)
    rolling20 = df["Adj Close"].rolling(window=20)
    df["BB_MID"] = rolling20.mean()
    df["BB_UP"]  = rolling20.mean() + 2 * rolling20.std()
    df["BB_LOW"] = rolling20.mean() - 2 * rolling20.std()
    df["BB_WIDTH"] = (df["BB_UP"] - df["BB_LOW"]) / df["BB_MID"]

    # 6. RSI (14)
    delta     = df["Adj Close"].diff()
    up        = delta.clip(lower=0)
    down      = -delta.clip(upper=0)
    roll_up   = up.rolling(window=14).mean()
    roll_down = down.rolling(window=14).mean()
    rs        = roll_up / roll_down
    df["RSI_14"] = 100 - (100 / (1 + rs))

    # 7. Average True Range (ATR, 14)
    high_low         = df["High"] - df["Low"]
    high_close_prev  = (df["High"] - df["Adj Close"].shift(1)).abs()
    low_close_prev   = (df["Low"] - df["Adj Close"].shift(1)).abs()
    tr               = pd.concat([high_low, high_close_prev, low_close_prev], axis=1).max(axis=1)
    df["ATR_14"]     = tr.rolling(window=14).mean()

    # 8. On‐Balance Volume (OBV)
    direction = np.sign(df["Adj Close"].diff()).fillna(0)
    df["OBV"] = (direction * df["Volume"]).fillna(0).cumsum()

    # 9. Rolling volatility and higher moments (10‐day)
    rolling_ret = df["log_ret"].rolling(window=10)
    df["Vol_10"]     = rolling_ret.std()
    df["Skew_10"]    = rolling_ret.apply(lambda x: x.skew(), raw=False)
    df["Kurt_10"]    = rolling_ret.apply(lambda x: x.kurt(), raw=False)

    # 10. Volume-based indicators: Volume‐Weighted Average Price (VWAP, 14‐day)
    pv = df["Adj Close"] * df["Volume"]
    df["VWAP_14"] = pv.rolling(window=14).sum() / df["Volume"].rolling(window=14).sum()

    # 11. Exponential volume‐weighted moving average (EVWMA, 14)
    df["EVWMA_14"] = (pv.ewm(span=14, adjust=False).mean() /
                      df["Volume"].ewm(span=14, adjust=False).mean())

    # 12. Exogenous log‐returns (SP500 & VIX)
    df["SP500_ret"] = np.log(df["SP500"] / df["SP500"].shift(1))
    df["VIX_ret"]   = np.log(df["VIX"] / df["VIX"].shift(1))

    # 13. Interaction features
    df["SMA5_x_VOL10"]   = df["SMA_5"] * df["Vol_10"]
    df["RSI14_x_ATR14"]  = df["RSI_14"] * df["ATR_14"]
    df["MACD_x_MACD_SIG"] = df["MACD"] * df["MACD_SIG"]

    # 14. Drop intermediate NaNs (due to rolling/lookback windows)
    df.dropna(inplace=True)
    return df

# %%
features = compute_technical_indicators(data)
features.dropna(inplace=True)

# %%
features["target"] = features["log_ret"].shift(-1)
features.dropna(inplace=True)

# %%
feature_cols = [
    "SMA_5", "SMA_10", "SMA_20",
    "EMA_10", "EMA_20",
    "MOM_10",
    "MACD", "MACD_SIG",
    "BB_MID", "BB_UP", "BB_LOW", "BB_WIDTH",
    "RSI_14",
    "ATR_14",
    "OBV",
    "Vol_10", "Skew_10", "Kurt_10",
    "VWAP_14",
    "SP500_ret", "VIX_ret"
]

# %%
features[["Adj Close"] + feature_cols + ["target"]].head()
# Out:
#             Adj Close      SMA_5     SMA_10     SMA_20     EMA_10     EMA_20  \
# Date
# 2010-02-01  25.399025  25.364608  25.821482  26.448284  25.764169  26.241193
# 2010-02-02  25.794811  25.419674  25.732861  26.358372  25.769740  26.198680
# 2010-02-03  26.457317  25.665749  25.695003  26.305027  25.894754  26.223312
# 2010-02-04  25.528084  25.720815  25.614125  26.212534  25.828087  26.157100
# 2010-02-05  25.416233  25.719094  25.576267  26.114018  25.753204  26.086541
#
#               MOM_10      MACD  MACD_SIG     BB_MID  ...     RSI_14    ATR_14  \
# Date                                                 ...
# 2010-02-01 -0.035294 -0.557844 -0.441690  26.448284  ...  29.185662  0.552501
# 2010-02-02 -0.033215 -0.523105 -0.457973  26.358372  ...  40.322703  0.559261
# 2010-02-03 -0.014107 -0.437076 -0.453794  26.305027  ...  44.181008  0.591833
# 2010-02-04 -0.030709 -0.438821 -0.450799  26.212534  ...  37.614715  0.638540
# 2010-02-05 -0.014677 -0.444110 -0.449461  26.114018  ...  39.728725  0.645301
#
#                    OBV    Vol_10   Skew_10   Kurt_10    VWAP_14  SP500_ret  \
# Date
# 2010-02-01 -69210500.0  0.011194 -0.230578 -0.908046  25.993952   0.014165
# 2010-02-02 -59109600.0  0.011569 -0.091154 -0.713922  25.939260   0.012890
# 2010-02-03 -43133400.0  0.014561  0.479918 -0.236411  25.932829  -0.005489
# 2010-02-04 -56540500.0  0.017502 -0.271576  0.369967  25.866522  -0.031636
# 2010-02-05 -68496600.0  0.016395 -0.532995  1.698868  25.802731   0.002893
#
#              VIX_ret    target
# Date
# 2010-02-01 -0.086052  0.015463
# 2010-02-02 -0.050385  0.025359
# 2010-02-03  0.005571 -0.035754
# 2010-02-04  0.188475 -0.004391
# 2010-02-05  0.001150 -0.002033
#
# [5 rows x 23 columns]

# %%
X = features[feature_cols].values
y = features["target"].values

tscv = TimeSeriesSplit(n_splits=5)
splits = list(tscv.split(X))

train_idx, val_idx = splits[0]
print(f"Fold 1 → train: {train_idx.min()}–{train_idx.max()}, val: {val_idx.min()}–{val_idx.max()}")

scaler = StandardScaler()
X_train = X[train_idx]
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled   = scaler.transform(X[val_idx])

y_train = y[train_idx]
y_val   = y[val_idx]
# Out:
# Fold 1 → train: 0–644, val: 645–1286

# %%
# Cell 5: Manual hyperparameter search for XGBoost with TimeSeriesSplit and early stopping

import itertools
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import numpy as np

# 1. Define parameter grid
param_grid = {
    "max_depth": [3,5,7,9],
    "learning_rate": [0.001, 0.003, 0.005],
    "subsample": [0.7,0.9],
    "colsample_bytree": [0.7,0.9],
    "reg_alpha": [0, 0.1, 1],
    "reg_lambda": [0, 0.1, 1, 5],
    "n_estimators": [1000, 2000, 3000]
}

# 2. Prepare X/y arrays from our precomputed 'features' DataFrame
X = features[feature_cols].values
y = features["target"].values

# 3. TimeSeriesSplit (same as before)
tscv = TimeSeriesSplit(n_splits=5)

# 4. Storage for results
search_results = []

# 5. Iterate over all combinations of hyperparameters
for max_depth, lr, subsample, colsample, reg_alpha, reg_lambda, n_estimators in itertools.product(
    param_grid["max_depth"],
    param_grid["learning_rate"],
    param_grid["subsample"],
    param_grid["colsample_bytree"],
    param_grid["reg_alpha"],
    param_grid["reg_lambda"],
    param_grid["n_estimators"]
):
    params = {
        "objective": "reg:squarederror",
        "tree_method": "hist",
        "verbosity": 0,
        "max_depth": max_depth,
        "eta": lr,
        "subsample": subsample,
        "colsample_bytree": colsample,
        "reg_alpha": reg_alpha,
        "reg_lambda": reg_lambda,
    }
    fold_rmse = []

    # 6. Perform time-series cross-validation
    for train_idx, val_idx in tscv.split(X):
        # Split into this fold's train/val
        X_train_fold = X[train_idx]
        y_train_fold = y[train_idx]
        X_val_fold   = X[val_idx]
        y_val_fold   = y[val_idx]

        # Scale using StandardScaler fitted on training fold only
        scaler_fold = StandardScaler()
        scaler_fold.fit(X_train_fold)
        X_train_sc = scaler_fold.transform(X_train_fold)
        X_val_sc   = scaler_fold.transform(X_val_fold)

        # Create DMatrix objects
        dtrain = xgb.DMatrix(X_train_sc, label=y_train_fold)
        dval   = xgb.DMatrix(X_val_sc,   label=y_val_fold)

        # Early-stopping settings
        evals = [(dtrain, "train"), (dval, "validation")]
        bst = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=n_estimators,
            evals=evals,
            early_stopping_rounds=50,
            verbose_eval=False
        )

        # Predict and compute RMSE on this fold's validation set
        preds = bst.predict(dval)
        rmse = np.sqrt(mean_squared_error(y_val_fold, preds))
        fold_rmse.append(rmse)

    # Average RMSE across folds
    avg_rmse = np.mean(fold_rmse)
    search_results.append({
        "max_depth": max_depth,
        "learning_rate": lr,
        "subsample": subsample,
        "colsample_bytree": colsample,
        "n_estimators": n_estimators,
        "avg_rmse": avg_rmse
    })
    print(f"Params: md={max_depth}, lr={lr}, ss={subsample}, cs={colsample}, reg_alpha={reg_alpha}, reg_lambda={reg_lambda}, ne={n_estimators} → Avg RMSE: {avg_rmse:.5f}")

best_result = min(search_results, key=lambda x: x["avg_rmse"])
print("\nBest hyperparameters:", best_result)
# Out:
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01633
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.001, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.7, cs=0.9, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01637
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.7, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.003, ss=0.9, cs=0.9, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01640
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01640
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01640
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01639
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01639
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01639
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01634
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=0.1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.7, reg_alpha=1, reg_lambda=5, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=1000 → Avg RMSE: 0.01642
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=2000 → Avg RMSE: 0.01642
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0, ne=3000 → Avg RMSE: 0.01642
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01641
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01641
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01641
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=1000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=2000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=1, ne=3000 → Avg RMSE: 0.01636
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0, reg_lambda=5, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=0.1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=1000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=2000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=1, ne=3000 → Avg RMSE: 0.01635
# Params: md=3, lr=0.005, ss=0.7, cs=0.9, reg_alpha=0.1, reg_lambda=5, ne=1000 → Avg RMSE: 0.01635

# %%
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# 1. Use the same best_params & best_n_estimators
params_full = {
    "objective": "reg:squarederror",
    "tree_method": "hist",
    "verbosity": 0,
    "max_depth": best_result["max_depth"],
    "eta": best_result["learning_rate"],
    "subsample": best_result["subsample"],
    "colsample_bytree": best_result["colsample_bytree"],
    "reg_alpha": best_result["reg_alpha"],
    "reg_lambda": best_result["reg_lambda"],
}
num_boost_round = best_result["n_estimators"]

# 2. Build X_all / y_all from the entire features DataFrame
X_all = features[feature_cols].values
y_all = features["target"].values

# 3. Split last 10 % of time-ordered data for early stopping
split_idx = int(len(X_all) * 0.9)
X_train_full = X_all[:split_idx]
y_train_full = y_all[:split_idx]
X_val_full   = X_all[split_idx:]
y_val_full   = y_all[split_idx:]

# 4. Scale on full training portion, apply to both
scaler_full = StandardScaler()
scaler_full.fit(X_train_full)
X_train_full_sc = scaler_full.transform(X_train_full)
X_val_full_sc   = scaler_full.transform(X_val_full)

# 5. Create DMatrix objects
dtrain_full = xgb.DMatrix(X_train_full_sc, label=y_train_full)
dval_full   = xgb.DMatrix(X_val_full_sc,   label=y_val_full)

# 6. Train with early stopping
evals_full = [(dtrain_full, "train"), (dval_full, "validation")]
bst_full = xgb.train(
    params=params_full,
    dtrain=dtrain_full,
    num_boost_round=num_boost_round,
    evals=evals_full,
    early_stopping_rounds=50,
    verbose_eval=True
)

# 7. Evaluate on the held-out 10 % validation
pred_full_val = bst_full.predict(dval_full)
rmse_full = np.sqrt(mean_squared_error(y_val_full, pred_full_val))
mae_full  = mean_absolute_error(y_val_full, pred_full_val)
hit_full  = np.mean(np.sign(pred_full_val) == np.sign(y_val_full))

print(f"Full-data → RMSE: {rmse_full:.5f}, MAE: {mae_full:.5f}, Hit Ratio: {hit_full:.3f}")
# Out:
# [0]	train-rmse:0.01648	validation-rmse:0.01859
# [1]	train-rmse:0.01647	validation-rmse:0.01858
# [2]	train-rmse:0.01646	validation-rmse:0.01858
# [3]	train-rmse:0.01645	validation-rmse:0.01858
# [4]	train-rmse:0.01645	validation-rmse:0.01857
# [5]	train-rmse:0.01644	validation-rmse:0.01857
# [6]	train-rmse:0.01643	validation-rmse:0.01857
# [7]	train-rmse:0.01643	validation-rmse:0.01856
# [8]	train-rmse:0.01642	validation-rmse:0.01855
# [9]	train-rmse:0.01641	validation-rmse:0.01855
# [10]	train-rmse:0.01641	validation-rmse:0.01855
# [11]	train-rmse:0.01640	validation-rmse:0.01855
# [12]	train-rmse:0.01639	validation-rmse:0.01855
# [13]	train-rmse:0.01638	validation-rmse:0.01854
# [14]	train-rmse:0.01637	validation-rmse:0.01853
# [15]	train-rmse:0.01636	validation-rmse:0.01853
# [16]	train-rmse:0.01636	validation-rmse:0.01853
# [17]	train-rmse:0.01635	validation-rmse:0.01854
# [18]	train-rmse:0.01634	validation-rmse:0.01854
# [19]	train-rmse:0.01634	validation-rmse:0.01854
# [20]	train-rmse:0.01633	validation-rmse:0.01854
# [21]	train-rmse:0.01633	validation-rmse:0.01854
# [22]	train-rmse:0.01632	validation-rmse:0.01855
# [23]	train-rmse:0.01631	validation-rmse:0.01855
# [24]	train-rmse:0.01630	validation-rmse:0.01855
# [25]	train-rmse:0.01629	validation-rmse:0.01855
# [26]	train-rmse:0.01629	validation-rmse:0.01855
# [27]	train-rmse:0.01628	validation-rmse:0.01854
# [28]	train-rmse:0.01627	validation-rmse:0.01854
# [29]	train-rmse:0.01626	validation-rmse:0.01853
# [30]	train-rmse:0.01626	validation-rmse:0.01853
# [31]	train-rmse:0.01625	validation-rmse:0.01853
# [32]	train-rmse:0.01625	validation-rmse:0.01853
# [33]	train-rmse:0.01624	validation-rmse:0.01853
# [34]	train-rmse:0.01623	validation-rmse:0.01853
# [35]	train-rmse:0.01623	validation-rmse:0.01852
# [36]	train-rmse:0.01622	validation-rmse:0.01852
# [37]	train-rmse:0.01622	validation-rmse:0.01852
# [38]	train-rmse:0.01621	validation-rmse:0.01852
# [39]	train-rmse:0.01621	validation-rmse:0.01851
# [40]	train-rmse:0.01620	validation-rmse:0.01851
# [41]	train-rmse:0.01619	validation-rmse:0.01851
# [42]	train-rmse:0.01618	validation-rmse:0.01850
# [43]	train-rmse:0.01618	validation-rmse:0.01850
# [44]	train-rmse:0.01617	validation-rmse:0.01850
# [45]	train-rmse:0.01616	validation-rmse:0.01850
# [46]	train-rmse:0.01615	validation-rmse:0.01850
# [47]	train-rmse:0.01615	validation-rmse:0.01850
# [48]	train-rmse:0.01614	validation-rmse:0.01849
# [49]	train-rmse:0.01614	validation-rmse:0.01849
# [50]	train-rmse:0.01613	validation-rmse:0.01849
# [51]	train-rmse:0.01613	validation-rmse:0.01850
# [52]	train-rmse:0.01612	validation-rmse:0.01850
# [53]	train-rmse:0.01612	validation-rmse:0.01850
# [54]	train-rmse:0.01611	validation-rmse:0.01850
# [55]	train-rmse:0.01610	validation-rmse:0.01851
# [56]	train-rmse:0.01610	validation-rmse:0.01851
# [57]	train-rmse:0.01609	validation-rmse:0.01851
# [58]	train-rmse:0.01609	validation-rmse:0.01850
# [59]	train-rmse:0.01608	validation-rmse:0.01851
# [60]	train-rmse:0.01608	validation-rmse:0.01850
# [61]	train-rmse:0.01607	validation-rmse:0.01850
# [62]	train-rmse:0.01607	validation-rmse:0.01850
# [63]	train-rmse:0.01606	validation-rmse:0.01850
# [64]	train-rmse:0.01606	validation-rmse:0.01850
# [65]	train-rmse:0.01606	validation-rmse:0.01850
# [66]	train-rmse:0.01605	validation-rmse:0.01850
# [67]	train-rmse:0.01605	validation-rmse:0.01850
# [68]	train-rmse:0.01604	validation-rmse:0.01850
# [69]	train-rmse:0.01603	validation-rmse:0.01850
# [70]	train-rmse:0.01603	validation-rmse:0.01850
# [71]	train-rmse:0.01602	validation-rmse:0.01850
# [72]	train-rmse:0.01602	validation-rmse:0.01850
# [73]	train-rmse:0.01601	validation-rmse:0.01850
# [74]	train-rmse:0.01601	validation-rmse:0.01850
# [75]	train-rmse:0.01600	validation-rmse:0.01850
# [76]	train-rmse:0.01600	validation-rmse:0.01849
# [77]	train-rmse:0.01599	validation-rmse:0.01849
# [78]	train-rmse:0.01598	validation-rmse:0.01849
# [79]	train-rmse:0.01598	validation-rmse:0.01849
# [80]	train-rmse:0.01598	validation-rmse:0.01849
# [81]	train-rmse:0.01597	validation-rmse:0.01849
# [82]	train-rmse:0.01597	validation-rmse:0.01849
# [83]	train-rmse:0.01597	validation-rmse:0.01849
# [84]	train-rmse:0.01596	validation-rmse:0.01849
# [85]	train-rmse:0.01596	validation-rmse:0.01848
# [86]	train-rmse:0.01595	validation-rmse:0.01848
# [87]	train-rmse:0.01595	validation-rmse:0.01848
# [88]	train-rmse:0.01594	validation-rmse:0.01848
# [89]	train-rmse:0.01594	validation-rmse:0.01848
# [90]	train-rmse:0.01593	validation-rmse:0.01848
# [91]	train-rmse:0.01593	validation-rmse:0.01849
# [92]	train-rmse:0.01593	validation-rmse:0.01848
# [93]	train-rmse:0.01592	validation-rmse:0.01848
# [94]	train-rmse:0.01592	validation-rmse:0.01848
# [95]	train-rmse:0.01591	validation-rmse:0.01848
# [96]	train-rmse:0.01591	validation-rmse:0.01848
# [97]	train-rmse:0.01591	validation-rmse:0.01848
# [98]	train-rmse:0.01590	validation-rmse:0.01848
# [99]	train-rmse:0.01590	validation-rmse:0.01848
# [100]	train-rmse:0.01589	validation-rmse:0.01848
# [101]	train-rmse:0.01589	validation-rmse:0.01848
# [102]	train-rmse:0.01589	validation-rmse:0.01847
# [103]	train-rmse:0.01588	validation-rmse:0.01847
# [104]	train-rmse:0.01588	validation-rmse:0.01848
# [105]	train-rmse:0.01588	validation-rmse:0.01848
# [106]	train-rmse:0.01587	validation-rmse:0.01848
# [107]	train-rmse:0.01587	validation-rmse:0.01848
# [108]	train-rmse:0.01586	validation-rmse:0.01847
# [109]	train-rmse:0.01586	validation-rmse:0.01847
# [110]	train-rmse:0.01586	validation-rmse:0.01847
# [111]	train-rmse:0.01585	validation-rmse:0.01848
# [112]	train-rmse:0.01585	validation-rmse:0.01848
# [113]	train-rmse:0.01584	validation-rmse:0.01848
# [114]	train-rmse:0.01584	validation-rmse:0.01848
# [115]	train-rmse:0.01583	validation-rmse:0.01848
# [116]	train-rmse:0.01583	validation-rmse:0.01848
# [117]	train-rmse:0.01583	validation-rmse:0.01848
# [118]	train-rmse:0.01582	validation-rmse:0.01847
# [119]	train-rmse:0.01582	validation-rmse:0.01847
# [120]	train-rmse:0.01581	validation-rmse:0.01847
# [121]	train-rmse:0.01581	validation-rmse:0.01848
# [122]	train-rmse:0.01581	validation-rmse:0.01848
# [123]	train-rmse:0.01580	validation-rmse:0.01848
# [124]	train-rmse:0.01580	validation-rmse:0.01848
# [125]	train-rmse:0.01579	validation-rmse:0.01848
# [126]	train-rmse:0.01579	validation-rmse:0.01847
# [127]	train-rmse:0.01579	validation-rmse:0.01848
# [128]	train-rmse:0.01578	validation-rmse:0.01847
# [129]	train-rmse:0.01578	validation-rmse:0.01848
# [130]	train-rmse:0.01578	validation-rmse:0.01848
# [131]	train-rmse:0.01577	validation-rmse:0.01848
# [132]	train-rmse:0.01577	validation-rmse:0.01848
# [133]	train-rmse:0.01577	validation-rmse:0.01848
# [134]	train-rmse:0.01576	validation-rmse:0.01847
# [135]	train-rmse:0.01576	validation-rmse:0.01847
# [136]	train-rmse:0.01576	validation-rmse:0.01847
# [137]	train-rmse:0.01575	validation-rmse:0.01847
# [138]	train-rmse:0.01575	validation-rmse:0.01847
# [139]	train-rmse:0.01575	validation-rmse:0.01847
# [140]	train-rmse:0.01575	validation-rmse:0.01848
# [141]	train-rmse:0.01574	validation-rmse:0.01848
# [142]	train-rmse:0.01574	validation-rmse:0.01848
# [143]	train-rmse:0.01574	validation-rmse:0.01848
# [144]	train-rmse:0.01573	validation-rmse:0.01848
# [145]	train-rmse:0.01573	validation-rmse:0.01848
# [146]	train-rmse:0.01573	validation-rmse:0.01847
# [147]	train-rmse:0.01573	validation-rmse:0.01847
# [148]	train-rmse:0.01572	validation-rmse:0.01847
# [149]	train-rmse:0.01572	validation-rmse:0.01847
# [150]	train-rmse:0.01571	validation-rmse:0.01847
# [151]	train-rmse:0.01571	validation-rmse:0.01847
# [152]	train-rmse:0.01571	validation-rmse:0.01848
# [153]	train-rmse:0.01571	validation-rmse:0.01847
# [154]	train-rmse:0.01570	validation-rmse:0.01847
# [155]	train-rmse:0.01570	validation-rmse:0.01847
# [156]	train-rmse:0.01570	validation-rmse:0.01847
# [157]	train-rmse:0.01569	validation-rmse:0.01847
# [158]	train-rmse:0.01569	validation-rmse:0.01847
# [159]	train-rmse:0.01569	validation-rmse:0.01847
# [160]	train-rmse:0.01568	validation-rmse:0.01847
# [161]	train-rmse:0.01568	validation-rmse:0.01847
# [162]	train-rmse:0.01568	validation-rmse:0.01847
# [163]	train-rmse:0.01567	validation-rmse:0.01847
# [164]	train-rmse:0.01567	validation-rmse:0.01846
# [165]	train-rmse:0.01566	validation-rmse:0.01846
# [166]	train-rmse:0.01566	validation-rmse:0.01846
# [167]	train-rmse:0.01566	validation-rmse:0.01846
# [168]	train-rmse:0.01566	validation-rmse:0.01846
# [169]	train-rmse:0.01565	validation-rmse:0.01846
# [170]	train-rmse:0.01565	validation-rmse:0.01846
# [171]	train-rmse:0.01565	validation-rmse:0.01845
# [172]	train-rmse:0.01564	validation-rmse:0.01845
# [173]	train-rmse:0.01564	validation-rmse:0.01845
# [174]	train-rmse:0.01564	validation-rmse:0.01845
# [175]	train-rmse:0.01564	validation-rmse:0.01845
# [176]	train-rmse:0.01563	validation-rmse:0.01845
# [177]	train-rmse:0.01563	validation-rmse:0.01846
# [178]	train-rmse:0.01563	validation-rmse:0.01846
# [179]	train-rmse:0.01562	validation-rmse:0.01846
# [180]	train-rmse:0.01562	validation-rmse:0.01846
# [181]	train-rmse:0.01562	validation-rmse:0.01846
# [182]	train-rmse:0.01561	validation-rmse:0.01846
# [183]	train-rmse:0.01561	validation-rmse:0.01846
# [184]	train-rmse:0.01561	validation-rmse:0.01846
# [185]	train-rmse:0.01561	validation-rmse:0.01846
# [186]	train-rmse:0.01560	validation-rmse:0.01846
# [187]	train-rmse:0.01560	validation-rmse:0.01846
# [188]	train-rmse:0.01560	validation-rmse:0.01846
# [189]	train-rmse:0.01560	validation-rmse:0.01846
# [190]	train-rmse:0.01559	validation-rmse:0.01846
# [191]	train-rmse:0.01559	validation-rmse:0.01846
# [192]	train-rmse:0.01559	validation-rmse:0.01846
# [193]	train-rmse:0.01559	validation-rmse:0.01845
# [194]	train-rmse:0.01559	validation-rmse:0.01845
# [195]	train-rmse:0.01558	validation-rmse:0.01845
# [196]	train-rmse:0.01558	validation-rmse:0.01845
# [197]	train-rmse:0.01558	validation-rmse:0.01845
# [198]	train-rmse:0.01557	validation-rmse:0.01845
# [199]	train-rmse:0.01557	validation-rmse:0.01845
# [200]	train-rmse:0.01557	validation-rmse:0.01844
# [201]	train-rmse:0.01557	validation-rmse:0.01844
# [202]	train-rmse:0.01556	validation-rmse:0.01844
# [203]	train-rmse:0.01556	validation-rmse:0.01844
# [204]	train-rmse:0.01556	validation-rmse:0.01844
# [205]	train-rmse:0.01556	validation-rmse:0.01844
# [206]	train-rmse:0.01556	validation-rmse:0.01844
# [207]	train-rmse:0.01555	validation-rmse:0.01844
# [208]	train-rmse:0.01555	validation-rmse:0.01844
# [209]	train-rmse:0.01555	validation-rmse:0.01844
# [210]	train-rmse:0.01555	validation-rmse:0.01844
# [211]	train-rmse:0.01554	validation-rmse:0.01844
# [212]	train-rmse:0.01554	validation-rmse:0.01844
# [213]	train-rmse:0.01554	validation-rmse:0.01844
# [214]	train-rmse:0.01554	validation-rmse:0.01844
# [215]	train-rmse:0.01553	validation-rmse:0.01844
# [216]	train-rmse:0.01553	validation-rmse:0.01844
# [217]	train-rmse:0.01553	validation-rmse:0.01844
# [218]	train-rmse:0.01553	validation-rmse:0.01844
# [219]	train-rmse:0.01552	validation-rmse:0.01844
# [220]	train-rmse:0.01552	validation-rmse:0.01844
# [221]	train-rmse:0.01552	validation-rmse:0.01844
# [222]	train-rmse:0.01552	validation-rmse:0.01844
# [223]	train-rmse:0.01552	validation-rmse:0.01844
# [224]	train-rmse:0.01551	validation-rmse:0.01844
# [225]	train-rmse:0.01551	validation-rmse:0.01844
# [226]	train-rmse:0.01551	validation-rmse:0.01844
# [227]	train-rmse:0.01551	validation-rmse:0.01844
# [228]	train-rmse:0.01550	validation-rmse:0.01844
# [229]	train-rmse:0.01550	validation-rmse:0.01844
# [230]	train-rmse:0.01550	validation-rmse:0.01844
# [231]	train-rmse:0.01550	validation-rmse:0.01844
# [232]	train-rmse:0.01549	validation-rmse:0.01844
# [233]	train-rmse:0.01549	validation-rmse:0.01844
# [234]	train-rmse:0.01549	validation-rmse:0.01844
# [235]	train-rmse:0.01549	validation-rmse:0.01844
# [236]	train-rmse:0.01549	validation-rmse:0.01844
# [237]	train-rmse:0.01548	validation-rmse:0.01844
# [238]	train-rmse:0.01548	validation-rmse:0.01843
# [239]	train-rmse:0.01548	validation-rmse:0.01843
# [240]	train-rmse:0.01548	validation-rmse:0.01843
# [241]	train-rmse:0.01548	validation-rmse:0.01843
# [242]	train-rmse:0.01547	validation-rmse:0.01844
# [243]	train-rmse:0.01547	validation-rmse:0.01844
# [244]	train-rmse:0.01547	validation-rmse:0.01843
# [245]	train-rmse:0.01547	validation-rmse:0.01843
# [246]	train-rmse:0.01546	validation-rmse:0.01843
# [247]	train-rmse:0.01546	validation-rmse:0.01843
# [248]	train-rmse:0.01546	validation-rmse:0.01842
# [249]	train-rmse:0.01546	validation-rmse:0.01842
# [250]	train-rmse:0.01545	validation-rmse:0.01842
# [251]	train-rmse:0.01545	validation-rmse:0.01842
# [252]	train-rmse:0.01545	validation-rmse:0.01843
# [253]	train-rmse:0.01545	validation-rmse:0.01842
# [254]	train-rmse:0.01544	validation-rmse:0.01842
# [255]	train-rmse:0.01544	validation-rmse:0.01843
# [256]	train-rmse:0.01544	validation-rmse:0.01843
# [257]	train-rmse:0.01544	validation-rmse:0.01843
# [258]	train-rmse:0.01543	validation-rmse:0.01843
# [259]	train-rmse:0.01543	validation-rmse:0.01843
# [260]	train-rmse:0.01543	validation-rmse:0.01843
# [261]	train-rmse:0.01543	validation-rmse:0.01843
# [262]	train-rmse:0.01543	validation-rmse:0.01843
# [263]	train-rmse:0.01542	validation-rmse:0.01843
# [264]	train-rmse:0.01542	validation-rmse:0.01843
# [265]	train-rmse:0.01542	validation-rmse:0.01843
# [266]	train-rmse:0.01541	validation-rmse:0.01843
# [267]	train-rmse:0.01541	validation-rmse:0.01843
# [268]	train-rmse:0.01541	validation-rmse:0.01843
# [269]	train-rmse:0.01541	validation-rmse:0.01843
# [270]	train-rmse:0.01540	validation-rmse:0.01843
# [271]	train-rmse:0.01540	validation-rmse:0.01843
# [272]	train-rmse:0.01540	validation-rmse:0.01843
# [273]	train-rmse:0.01540	validation-rmse:0.01843
# [274]	train-rmse:0.01539	validation-rmse:0.01843
# [275]	train-rmse:0.01539	validation-rmse:0.01843
# [276]	train-rmse:0.01539	validation-rmse:0.01843
# [277]	train-rmse:0.01539	validation-rmse:0.01843
# [278]	train-rmse:0.01538	validation-rmse:0.01843
# [279]	train-rmse:0.01538	validation-rmse:0.01842
# [280]	train-rmse:0.01538	validation-rmse:0.01842
# [281]	train-rmse:0.01537	validation-rmse:0.01842
# [282]	train-rmse:0.01537	validation-rmse:0.01842
# [283]	train-rmse:0.01537	validation-rmse:0.01842
# [284]	train-rmse:0.01537	validation-rmse:0.01841
# [285]	train-rmse:0.01537	validation-rmse:0.01841
# [286]	train-rmse:0.01536	validation-rmse:0.01841
# [287]	train-rmse:0.01536	validation-rmse:0.01841
# [288]	train-rmse:0.01536	validation-rmse:0.01841
# [289]	train-rmse:0.01536	validation-rmse:0.01840
# [290]	train-rmse:0.01535	validation-rmse:0.01840
# [291]	train-rmse:0.01535	validation-rmse:0.01840
# [292]	train-rmse:0.01535	validation-rmse:0.01840
# [293]	train-rmse:0.01534	validation-rmse:0.01840
# [294]	train-rmse:0.01534	validation-rmse:0.01840
# [295]	train-rmse:0.01534	validation-rmse:0.01840
# [296]	train-rmse:0.01534	validation-rmse:0.01840
# [297]	train-rmse:0.01533	validation-rmse:0.01839
# [298]	train-rmse:0.01533	validation-rmse:0.01839
# [299]	train-rmse:0.01533	validation-rmse:0.01839
# [300]	train-rmse:0.01533	validation-rmse:0.01840
# [301]	train-rmse:0.01532	validation-rmse:0.01839
# [302]	train-rmse:0.01532	validation-rmse:0.01839
# [303]	train-rmse:0.01532	validation-rmse:0.01839
# [304]	train-rmse:0.01532	validation-rmse:0.01840
# [305]	train-rmse:0.01532	validation-rmse:0.01839
# [306]	train-rmse:0.01532	validation-rmse:0.01839
# [307]	train-rmse:0.01531	validation-rmse:0.01839
# [308]	train-rmse:0.01531	validation-rmse:0.01838
# [309]	train-rmse:0.01531	validation-rmse:0.01839
# [310]	train-rmse:0.01530	validation-rmse:0.01839
# [311]	train-rmse:0.01530	validation-rmse:0.01839
# [312]	train-rmse:0.01530	validation-rmse:0.01839
# [313]	train-rmse:0.01530	validation-rmse:0.01839
# [314]	train-rmse:0.01529	validation-rmse:0.01839
# [315]	train-rmse:0.01529	validation-rmse:0.01839
# [316]	train-rmse:0.01529	validation-rmse:0.01839
# [317]	train-rmse:0.01528	validation-rmse:0.01838
# [318]	train-rmse:0.01528	validation-rmse:0.01838
# [319]	train-rmse:0.01528	validation-rmse:0.01839
# [320]	train-rmse:0.01528	validation-rmse:0.01839
# [321]	train-rmse:0.01528	validation-rmse:0.01839
# [322]	train-rmse:0.01528	validation-rmse:0.01838
# [323]	train-rmse:0.01527	validation-rmse:0.01838
# [324]	train-rmse:0.01527	validation-rmse:0.01838
# [325]	train-rmse:0.01527	validation-rmse:0.01838
# [326]	train-rmse:0.01527	validation-rmse:0.01838
# [327]	train-rmse:0.01527	validation-rmse:0.01838
# [328]	train-rmse:0.01526	validation-rmse:0.01838
# [329]	train-rmse:0.01526	validation-rmse:0.01838
# [330]	train-rmse:0.01526	validation-rmse:0.01838
# [331]	train-rmse:0.01526	validation-rmse:0.01838
# [332]	train-rmse:0.01525	validation-rmse:0.01837
# [333]	train-rmse:0.01525	validation-rmse:0.01837
# [334]	train-rmse:0.01525	validation-rmse:0.01837
# [335]	train-rmse:0.01525	validation-rmse:0.01837
# [336]	train-rmse:0.01525	validation-rmse:0.01837
# [337]	train-rmse:0.01524	validation-rmse:0.01837
# [338]	train-rmse:0.01524	validation-rmse:0.01837
# [339]	train-rmse:0.01524	validation-rmse:0.01837
# [340]	train-rmse:0.01524	validation-rmse:0.01837
# [341]	train-rmse:0.01523	validation-rmse:0.01837
# [342]	train-rmse:0.01523	validation-rmse:0.01837
# [343]	train-rmse:0.01523	validation-rmse:0.01837
# [344]	train-rmse:0.01523	validation-rmse:0.01837
# [345]	train-rmse:0.01523	validation-rmse:0.01837
# [346]	train-rmse:0.01522	validation-rmse:0.01837
# [347]	train-rmse:0.01522	validation-rmse:0.01837
# [348]	train-rmse:0.01522	validation-rmse:0.01837
# [349]	train-rmse:0.01522	validation-rmse:0.01837
# [350]	train-rmse:0.01522	validation-rmse:0.01837
# [351]	train-rmse:0.01521	validation-rmse:0.01837
# [352]	train-rmse:0.01521	validation-rmse:0.01837
# [353]	train-rmse:0.01521	validation-rmse:0.01837
# [354]	train-rmse:0.01521	validation-rmse:0.01837
# [355]	train-rmse:0.01520	validation-rmse:0.01837
# [356]	train-rmse:0.01520	validation-rmse:0.01837
# [357]	train-rmse:0.01520	validation-rmse:0.01837
# [358]	train-rmse:0.01520	validation-rmse:0.01837
# [359]	train-rmse:0.01520	validation-rmse:0.01836
# [360]	train-rmse:0.01519	validation-rmse:0.01836
# [361]	train-rmse:0.01519	validation-rmse:0.01837
# [362]	train-rmse:0.01519	validation-rmse:0.01837
# [363]	train-rmse:0.01519	validation-rmse:0.01837
# [364]	train-rmse:0.01518	validation-rmse:0.01837
# [365]	train-rmse:0.01518	validation-rmse:0.01837
# [366]	train-rmse:0.01518	validation-rmse:0.01837
# [367]	train-rmse:0.01518	validation-rmse:0.01837
# [368]	train-rmse:0.01518	validation-rmse:0.01837
# [369]	train-rmse:0.01517	validation-rmse:0.01837
# [370]	train-rmse:0.01517	validation-rmse:0.01837
# [371]	train-rmse:0.01517	validation-rmse:0.01837
# [372]	train-rmse:0.01516	validation-rmse:0.01837
# [373]	train-rmse:0.01516	validation-rmse:0.01837
# [374]	train-rmse:0.01516	validation-rmse:0.01837
# [375]	train-rmse:0.01516	validation-rmse:0.01837
# [376]	train-rmse:0.01516	validation-rmse:0.01837
# [377]	train-rmse:0.01515	validation-rmse:0.01837
# [378]	train-rmse:0.01515	validation-rmse:0.01837
# [379]	train-rmse:0.01515	validation-rmse:0.01837
# [380]	train-rmse:0.01515	validation-rmse:0.01837
# [381]	train-rmse:0.01515	validation-rmse:0.01837
# [382]	train-rmse:0.01514	validation-rmse:0.01837
# [383]	train-rmse:0.01514	validation-rmse:0.01837
# [384]	train-rmse:0.01514	validation-rmse:0.01837
# [385]	train-rmse:0.01514	validation-rmse:0.01838
# [386]	train-rmse:0.01513	validation-rmse:0.01838
# [387]	train-rmse:0.01513	validation-rmse:0.01838
# [388]	train-rmse:0.01513	validation-rmse:0.01837
# [389]	train-rmse:0.01513	validation-rmse:0.01837
# [390]	train-rmse:0.01512	validation-rmse:0.01837
# [391]	train-rmse:0.01512	validation-rmse:0.01837
# [392]	train-rmse:0.01512	validation-rmse:0.01837
# [393]	train-rmse:0.01512	validation-rmse:0.01837
# [394]	train-rmse:0.01512	validation-rmse:0.01837
# [395]	train-rmse:0.01511	validation-rmse:0.01837
# [396]	train-rmse:0.01511	validation-rmse:0.01837
# [397]	train-rmse:0.01511	validation-rmse:0.01838
# [398]	train-rmse:0.01511	validation-rmse:0.01838
# [399]	train-rmse:0.01511	validation-rmse:0.01838
# [400]	train-rmse:0.01510	validation-rmse:0.01838
# [401]	train-rmse:0.01510	validation-rmse:0.01838
# [402]	train-rmse:0.01510	validation-rmse:0.01838
# [403]	train-rmse:0.01510	validation-rmse:0.01838
# [404]	train-rmse:0.01510	validation-rmse:0.01838
# [405]	train-rmse:0.01509	validation-rmse:0.01838
# [406]	train-rmse:0.01509	validation-rmse:0.01838
# [407]	train-rmse:0.01509	validation-rmse:0.01838
# [408]	train-rmse:0.01509	validation-rmse:0.01838
# [409]	train-rmse:0.01509	validation-rmse:0.01838
# [410]	train-rmse:0.01508	validation-rmse:0.01838
# [411]	train-rmse:0.01508	validation-rmse:0.01838
# [412]	train-rmse:0.01508	validation-rmse:0.01838
# [413]	train-rmse:0.01508	validation-rmse:0.01838
# [414]	train-rmse:0.01507	validation-rmse:0.01838
# [415]	train-rmse:0.01507	validation-rmse:0.01838
# [416]	train-rmse:0.01507	validation-rmse:0.01838
# [417]	train-rmse:0.01507	validation-rmse:0.01838
# [418]	train-rmse:0.01507	validation-rmse:0.01838
# [419]	train-rmse:0.01506	validation-rmse:0.01838
# [420]	train-rmse:0.01506	validation-rmse:0.01838
# [421]	train-rmse:0.01506	validation-rmse:0.01838
# [422]	train-rmse:0.01506	validation-rmse:0.01838
# [423]	train-rmse:0.01506	validation-rmse:0.01838
# [424]	train-rmse:0.01505	validation-rmse:0.01838
# [425]	train-rmse:0.01505	validation-rmse:0.01838
# [426]	train-rmse:0.01505	validation-rmse:0.01838
# [427]	train-rmse:0.01505	validation-rmse:0.01839
# [428]	train-rmse:0.01505	validation-rmse:0.01838
# [429]	train-rmse:0.01504	validation-rmse:0.01838
# [430]	train-rmse:0.01504	validation-rmse:0.01838
# [431]	train-rmse:0.01504	validation-rmse:0.01838
# [432]	train-rmse:0.01504	validation-rmse:0.01838
# [433]	train-rmse:0.01503	validation-rmse:0.01838
# [434]	train-rmse:0.01503	validation-rmse:0.01838
# [435]	train-rmse:0.01503	validation-rmse:0.01838
# [436]	train-rmse:0.01503	validation-rmse:0.01838
# [437]	train-rmse:0.01503	validation-rmse:0.01838
# [438]	train-rmse:0.01502	validation-rmse:0.01839
# [439]	train-rmse:0.01502	validation-rmse:0.01839
# [440]	train-rmse:0.01502	validation-rmse:0.01839
# [441]	train-rmse:0.01502	validation-rmse:0.01839
# [442]	train-rmse:0.01502	validation-rmse:0.01838
# [443]	train-rmse:0.01501	validation-rmse:0.01839
# [444]	train-rmse:0.01501	validation-rmse:0.01838
# [445]	train-rmse:0.01501	validation-rmse:0.01838
# [446]	train-rmse:0.01501	validation-rmse:0.01838
# [447]	train-rmse:0.01500	validation-rmse:0.01838
# [448]	train-rmse:0.01500	validation-rmse:0.01838
# [449]	train-rmse:0.01500	validation-rmse:0.01838
# [450]	train-rmse:0.01500	validation-rmse:0.01838
# [451]	train-rmse:0.01500	validation-rmse:0.01838
# [452]	train-rmse:0.01499	validation-rmse:0.01838
# [453]	train-rmse:0.01499	validation-rmse:0.01838
# [454]	train-rmse:0.01499	validation-rmse:0.01838
# [455]	train-rmse:0.01499	validation-rmse:0.01838
# [456]	train-rmse:0.01498	validation-rmse:0.01838
# [457]	train-rmse:0.01498	validation-rmse:0.01838
# [458]	train-rmse:0.01498	validation-rmse:0.01838
# [459]	train-rmse:0.01498	validation-rmse:0.01838
# [460]	train-rmse:0.01498	validation-rmse:0.01837
# Full-data → RMSE: 0.01837, MAE: 0.01164, Hit Ratio: 0.518
